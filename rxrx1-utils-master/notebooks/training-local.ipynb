# %%
import json
import os
import sys
import tensorflow as tf
import sys
import pandas as pd
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sys.path.append('./rxrx1-utils')
from rxrx.main import main

# %% [markdown]
# ## Train
#
# Set `MODEL_DIR`. The code will write your checkpoins to this directory.

# %%
# !nvidia-smi
# Out:
# Fri Jul 19 17:21:26 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.67       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 108...  On   | 00000000:05:00.0  On |                  N/A |
# | 24%   44C    P8    11W / 250W |    258MiB / 11175MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce GTX 108...  On   | 00000000:06:00.0 Off |                  N/A |
# | 23%   40C    P8     9W / 250W |    149MiB / 11178MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce GTX 108...  On   | 00000000:09:00.0 Off |                  N/A |
# | 23%   42C    P8     9W / 250W |    149MiB / 11178MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   3  GeForce GTX 108...  On   | 00000000:0A:00.0 Off |                  N/A |
# | 23%   33C    P8     8W / 250W |    149MiB / 11178MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    0      1493      G   /usr/lib/xorg/Xorg                            39MiB |
# |    0      1528      G   /usr/bin/gnome-shell                          69MiB |
# |    0     25657      C   ...er1/anaconda3/envs/recursion/bin/python   137MiB |
# |    1     25657      C   ...er1/anaconda3/envs/recursion/bin/python   137MiB |
# |    2     25657      C   ...er1/anaconda3/envs/recursion/bin/python   137MiB |
# |    3     25657      C   ...er1/anaconda3/envs/recursion/bin/python   137MiB |
# +-----------------------------------------------------------------------------+

# %%
MODEL_DIR = '/mnt/f43ef2ec-a5a4-4c36-bdb9-b63ec645a265/kaggle/recursion/model'
URL_BASE_PATH = '/mnt/f43ef2ec-a5a4-4c36-bdb9-b63ec645a265/kaggle/recursion/data/processed/random-42'

tf.logging.set_verbosity(tf.logging.INFO)
main(url_base_path=URL_BASE_PATH,
     model_dir=MODEL_DIR,
     train_epochs=1,
     train_batch_size = 32,
     num_train_images=73030,
     epochs_per_loop=1,
     log_step_count_epochs=1,
     tf_precision='float16',
     n_classes=1108,
     momentum=0.9,
     weight_decay=1e-4,
     base_learning_rate=0.2,
     warmup_epochs=5)
# Out:
# INFO:tensorflow:Device is available but not used by distribute strategy: /device:CPU:0
# INFO:tensorflow:Device is available but not used by distribute strategy: /device:XLA_CPU:0
# INFO:tensorflow:Device is available but not used by distribute strategy: /device:XLA_GPU:0
# INFO:tensorflow:Device is available but not used by distribute strategy: /device:XLA_GPU:1
# INFO:tensorflow:Device is available but not used by distribute strategy: /device:XLA_GPU:2
# INFO:tensorflow:Device is available but not used by distribute strategy: /device:XLA_GPU:3
# INFO:tensorflow:Configured nccl all-reduce.
# INFO:tensorflow:Initializing RunConfig with distribution strategies.
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Using config: {'_model_dir': '/mnt/f43ef2ec-a5a4-4c36-bdb9-b63ec645a265/kaggle/recursion/model', '_tf_random_seed': None, '_save_summary_steps': 2282, '_save_checkpoints_steps': 2282, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 2282, '_train_distribute': <tensorflow.contrib.distribute.python.mirrored_strategy.MirroredStrategy object at 0x7f13984a1048>, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f13984a15c0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_distribute_coordinator_mode': None}
# INFO:tensorflow:Train glob: /mnt/f43ef2ec-a5a4-4c36-bdb9-b63ec645a265/kaggle/recursion/data/processed/random-42/train/*.tfrecord
# INFO:tensorflow:Training for 2282 steps (1.00 epochs in total). Current step 0.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:features shape in resnet_model_fn:(8, 512, 512, 6)
# INFO:tensorflow:Error reported to Coordinator: Negative dimension size caused by subtracting 2048 from 16 for 'average_pooling2d/AvgPool' (op: 'AvgPool') with input shapes: [8,2048,16,1].
# Traceback (most recent call last):
#   File "/home/user1/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1659, in _create_c_op
#     c_op = c_api.TF_FinishOperation(op_desc)
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Negative dimension size caused by subtracting 2048 from 16 for 'average_pooling2d/AvgPool' (op: 'AvgPool') with input shapes: [8,2048,16,1].
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/user1/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/training/coordinator.py", line 297, in stop_on_exception
#     yield
#   File "/home/user1/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/distribute/mirrored_strategy.py", line 852, in run
#     self.main_result = self.main_fn(*self.main_args, **self.main_kwargs)
#   File "/home/user1/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow_estimator/python/estimator/estimator.py", line 1112, in _call_model_fn
#     model_fn_results = self._model_fn(features=features, **kwargs)
#   File "./rxrx1-utils/rxrx/main.py", line 88, in resnet_model_fn
#     logits = build_network()
#   File "./rxrx1-utils/rxrx/main.py", line 86, in build_network
#     inputs=features, is_training=(mode == tf.estimator.ModeKeys.TRAIN))
#   File "./rxrx1-utils/rxrx/official_resnet.py", line 442, in model
#     data_format=data_format)
#   File "/home/user1/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py", line 324, in new_func
#     return func(*args, **kwargs)
#   File "/home/user1/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/layers/pooling.py", line 241, in average_pooling2d
#     return layer.apply(inputs)
#   File "/home/user1/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py", line 1227, in apply
#     return self.__call__(inputs, *args, **kwargs)
#   File "/home/user1/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/layers/base.py", line 530, in __call__
#     outputs = super(Layer, self).__call__(inputs, *args, **kwargs)
#   File "/home/user1/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py", line 554, in __call__
#     outputs = self.call(inputs, *args, **kwargs)
#   File "/home/user1/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/keras/layers/pooling.py", line 256, in call
#     data_format=conv_utils.convert_data_format(self.data_format, 4))
#   File "/home/user1/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/ops/nn_ops.py", line 2718, in avg_pool
#     name=name)
#   File "/home/user1/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/ops/gen_nn_ops.py", line 93, in avg_pool
#     data_format=data_format, name=name)
#   File "/home/user1/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 788, in _apply_op_helper
#     op_def=op_def)
#   File "/home/user1/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "/home/user1/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 3300, in create_op
#     op_def=op_def)
#   File "/home/user1/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1823, in __init__
#     control_input_ops)
#   File "/home/user1/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1662, in _create_c_op
#     raise ValueError(str(e))
# ValueError: Negative dimension size caused by subtracting 2048 from 16 for 'average_pooling2d/AvgPool' (op: 'AvgPool') with input shapes: [8,2048,16,1].
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1658   try:
# -> 1659     c_op = c_api.TF_FinishOperation(op_desc)
#    1660   except errors.InvalidArgumentError as e:
#
# InvalidArgumentError: Negative dimension size caused by subtracting 2048 from 16 for 'average_pooling2d/AvgPool' (op: 'AvgPool') with input shapes: [8,2048,16,1].
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-b851eae98a5f> in <module>
#      15      weight_decay=1e-4,
#      16      base_learning_rate=0.2,
# ---> 17      warmup_epochs=5)
#
# /mnt/f43ef2ec-a5a4-4c36-bdb9-b63ec645a265/kaggle/recursion/rxrx1-utils-master/notebooks/rxrx1-utils/rxrx/main.py in main(url_base_path, model_dir, train_epochs, train_batch_size, num_train_images, epochs_per_loop, log_step_count_epochs, tf_precision, n_classes, momentum, weight_decay, base_learning_rate, warmup_epochs, input_fn_params, resnet_depth)
#     293     start_timestamp = time.time()  # This time will include compilation time
#     294
# --> 295     resnet_classifier.train(input_fn=train_input_fn, max_steps=train_steps)
#     296
#     297     tf.logging.info('Finished training up to step %d. Elapsed seconds %d.',
#
# ~/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow_estimator/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     356
#     357       saving_listeners = _check_listeners_type(saving_listeners)
# --> 358       loss = self._train_model(input_fn, hooks, saving_listeners)
#     359       logging.info('Loss for final step: %s.', loss)
#     360       return self
#
# ~/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1120   def _train_model(self, input_fn, hooks, saving_listeners):
#    1121     if self._train_distribution:
# -> 1122       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1123     else:
#    1124       return self._train_model_default(input_fn, hooks, saving_listeners)
#
# ~/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model_distributed(self, input_fn, hooks, saving_listeners)
#    1183       self._config._train_distribute.configure(self._config.session_config)
#    1184       return self._actual_train_model_distributed(
# -> 1185           self._config._train_distribute, input_fn, hooks, saving_listeners)
#    1186     # pylint: enable=protected-access
#    1187
#
# ~/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow_estimator/python/estimator/estimator.py in _actual_train_model_distributed(self, strategy, input_fn, hooks, saving_listeners)
#    1252                     labels,  # although this will be None it seems
#    1253                     model_fn_lib.ModeKeys.TRAIN,
# -> 1254                     self.config))
#    1255           loss = strategy.reduce(distribute_lib.get_loss_reduction(),
#    1256                                  grouped_estimator_spec.loss)
#
# ~/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py in call_for_each_replica(self, fn, args, kwargs)
#    1197     if kwargs is None:
#    1198       kwargs = {}
# -> 1199     return self._call_for_each_replica(fn, args, kwargs)
#    1200
#    1201   def _call_for_each_replica(self, fn, args, kwargs):
#
# ~/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/distribute/mirrored_strategy.py in _call_for_each_replica(self, fn, args, kwargs)
#     639
#     640   def _call_for_each_replica(self, fn, args, kwargs):
# --> 641     return _call_for_each_replica(self._container_strategy(), fn, args, kwargs)
#     642
#     643   def _configure(self,
#
# ~/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/distribute/mirrored_strategy.py in _call_for_each_replica(distribution, fn, args, kwargs)
#     187     for t in threads:
#     188       t.should_run.set()
# --> 189     coord.join(threads)
#     190
#     191   return values.regroup({t.device: t.main_result for t in threads})
#
# ~/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/training/coordinator.py in join(self, threads, stop_grace_period_secs, ignore_live_threads)
#     387       self._registered_threads = set()
#     388       if self._exc_info_to_raise:
# --> 389         six.reraise(*self._exc_info_to_raise)
#     390       elif stragglers:
#     391         if ignore_live_threads:
#
# ~/anaconda3/envs/recursion/lib/python3.6/site-packages/six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# ~/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/training/coordinator.py in stop_on_exception(self)
#     295     """
#     296     try:
# --> 297       yield
#     298     except:  # pylint: disable=bare-except
#     299       self.request_stop(ex=sys.exc_info())
#
# ~/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/distribute/mirrored_strategy.py in run(self)
#     850                 self._captured_var_scope, reuse=self.replica_id > 0), \
#     851             variable_scope.variable_creator_scope(self.variable_creator_fn):
# --> 852           self.main_result = self.main_fn(*self.main_args, **self.main_kwargs)
#     853           self.done = True
#     854       finally:
#
# ~/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow_estimator/python/estimator/estimator.py in _call_model_fn(self, features, labels, mode, config)
#    1110
#    1111     logging.info('Calling model_fn.')
# -> 1112     model_fn_results = self._model_fn(features=features, **kwargs)
#    1113     logging.info('Done calling model_fn.')
#    1114
#
# /mnt/f43ef2ec-a5a4-4c36-bdb9-b63ec645a265/kaggle/recursion/rxrx1-utils-master/notebooks/rxrx1-utils/rxrx/main.py in resnet_model_fn(features, labels, mode, n_classes, num_train_images, train_batch_size, momentum, weight_decay, base_learning_rate, warmup_epochs, iterations_per_loop, model_dir, tf_precision, resnet_depth)
#      86             inputs=features, is_training=(mode == tf.estimator.ModeKeys.TRAIN))
#      87
# ---> 88     logits = build_network()
#      89
#      90     if mode == tf.estimator.ModeKeys.PREDICT:
#
# /mnt/f43ef2ec-a5a4-4c36-bdb9-b63ec645a265/kaggle/recursion/rxrx1-utils-master/notebooks/rxrx1-utils/rxrx/main.py in build_network()
#      84             num_classes=n_classes)
#      85         return network(
# ---> 86             inputs=features, is_training=(mode == tf.estimator.ModeKeys.TRAIN))
#      87
#      88     logits = build_network()
#
# /mnt/f43ef2ec-a5a4-4c36-bdb9-b63ec645a265/kaggle/recursion/rxrx1-utils-master/notebooks/rxrx1-utils/rxrx/official_resnet.py in model(inputs, is_training)
#     440     inputs = tf.layers.average_pooling2d(
#     441         inputs=inputs, pool_size=pool_size, strides=1, padding='VALID',
# --> 442         data_format=data_format)
#     443     inputs = tf.identity(inputs, 'final_avg_pool')
#     444     inputs = tf.reshape(
#
# ~/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     322               'in a future version' if date is None else ('after %s' % date),
#     323               instructions)
# --> 324       return func(*args, **kwargs)
#     325     return tf_decorator.make_decorator(
#     326         func, new_func, 'deprecated',
#
# ~/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/layers/pooling.py in average_pooling2d(inputs, pool_size, strides, padding, data_format, name)
#     239                            padding=padding, data_format=data_format,
#     240                            name=name)
# --> 241   return layer.apply(inputs)
#     242
#     243
#
# ~/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in apply(self, inputs, *args, **kwargs)
#    1225       Output tensor(s).
#    1226     """
# -> 1227     return self.__call__(inputs, *args, **kwargs)
#    1228
#    1229   @doc_controls.for_subclass_implementers
#
# ~/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/layers/base.py in __call__(self, inputs, *args, **kwargs)
#     528
#     529       # Actually call layer
# --> 530       outputs = super(Layer, self).__call__(inputs, *args, **kwargs)
#     531
#     532     if not context.executing_eagerly():
#
# ~/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     552             # In graph mode, failure to build the layer's graph
#     553             # implies a user-side bug. We don't catch exceptions.
# --> 554             outputs = self.call(inputs, *args, **kwargs)
#     555           else:
#     556             try:
#
# ~/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/keras/layers/pooling.py in call(self, inputs)
#     254         strides=strides,
#     255         padding=self.padding.upper(),
# --> 256         data_format=conv_utils.convert_data_format(self.data_format, 4))
#     257     return outputs
#     258
#
# ~/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/ops/nn_ops.py in avg_pool(value, ksize, strides, padding, data_format, name)
#    2716         padding=padding,
#    2717         data_format=data_format,
# -> 2718         name=name)
#    2719
#    2720
#
# ~/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/ops/gen_nn_ops.py in avg_pool(value, ksize, strides, padding, data_format, name)
#      91   _, _, _op = _op_def_lib._apply_op_helper(
#      92         "AvgPool", value=value, ksize=ksize, strides=strides, padding=padding,
# ---> 93                    data_format=data_format, name=name)
#      94   _result = _op.outputs[:]
#      95   _inputs_flat = _op.inputs
#
# ~/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     786         op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     787                          input_types=input_types, attrs=attr_protos,
# --> 788                          op_def=op_def)
#     789       return output_structure, op_def.is_stateful, op
#     790
#
# ~/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     505                 'in a future version' if date is None else ('after %s' % date),
#     506                 instructions)
# --> 507       return func(*args, **kwargs)
#     508
#     509     doc = _add_deprecated_arg_notice_to_docstring(
#
# ~/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in create_op(***failed resolving arguments***)
#    3298           input_types=input_types,
#    3299           original_op=self._default_original_op,
# -> 3300           op_def=op_def)
#    3301       self._create_op_helper(ret, compute_device=compute_device)
#    3302     return ret
#
# ~/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1821           op_def, inputs, node_def.attr)
#    1822       self._c_op = _create_c_op(self._graph, node_def, grouped_inputs,
# -> 1823                                 control_input_ops)
#    1824
#    1825     # Initialize self._outputs.
#
# ~/anaconda3/envs/recursion/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1660   except errors.InvalidArgumentError as e:
#    1661     # Convert to ValueError for backwards compatibility.
# -> 1662     raise ValueError(str(e))
#    1663
#    1664   return c_op
#
# ValueError: Negative dimension size caused by subtracting 2048 from 16 for 'average_pooling2d/AvgPool' (op: 'AvgPool') with input shapes: [8,2048,16,1].

# %%
sample_df = pd.read_csv("../../data/raw/sample_submission.csv")

# %%
sample_df
# Out:
#               id_code  sirna
# 0      HEPG2-08_1_B03    911
# 1      HEPG2-08_1_B04    911
# 2      HEPG2-08_1_B05    911
# 3      HEPG2-08_1_B06    911
# 4      HEPG2-08_1_B07    911
# 5      HEPG2-08_1_B08    911
# 6      HEPG2-08_1_B09    911
# 7      HEPG2-08_1_B10    911
# 8      HEPG2-08_1_B11    911
# 9      HEPG2-08_1_B12    911
# 10     HEPG2-08_1_B13    911
# 11     HEPG2-08_1_B14    911
# 12     HEPG2-08_1_B15    911
# 13     HEPG2-08_1_B16    911
# 14     HEPG2-08_1_B17    911
# 15     HEPG2-08_1_B18    911
# 16     HEPG2-08_1_B19    911
# 17     HEPG2-08_1_B20    911
# 18     HEPG2-08_1_B21    911
# 19     HEPG2-08_1_B22    911
# 20     HEPG2-08_1_B23    911
# 21     HEPG2-08_1_C02    911
# 22     HEPG2-08_1_C04    911
# 23     HEPG2-08_1_C05    911
# 24     HEPG2-08_1_C06    911
# 25     HEPG2-08_1_C08    911
# 26     HEPG2-08_1_C09    911
# 27     HEPG2-08_1_C10    911
# 28     HEPG2-08_1_C12    911
# 29     HEPG2-08_1_C13    911
# ...               ...    ...
# 19867   U2OS-05_4_N16    911
# 19868   U2OS-05_4_N17    911
# 19869   U2OS-05_4_N18    911
# 19870   U2OS-05_4_N19    911
# 19871   U2OS-05_4_N20    911
# 19872   U2OS-05_4_N21    911
# 19873   U2OS-05_4_N22    911
# 19874   U2OS-05_4_N23    911
# 19875   U2OS-05_4_O02    911
# 19876   U2OS-05_4_O03    911
# 19877   U2OS-05_4_O04    911
# 19878   U2OS-05_4_O05    911
# 19879   U2OS-05_4_O06    911
# 19880   U2OS-05_4_O07    911
# 19881   U2OS-05_4_O08    911
# 19882   U2OS-05_4_O09    911
# 19883   U2OS-05_4_O10    911
# 19884   U2OS-05_4_O11    911
# 19885   U2OS-05_4_O12    911
# 19886   U2OS-05_4_O13    911
# 19887   U2OS-05_4_O14    911
# 19888   U2OS-05_4_O15    911
# 19889   U2OS-05_4_O16    911
# 19890   U2OS-05_4_O17    911
# 19891   U2OS-05_4_O18    911
# 19892   U2OS-05_4_O19    911
# 19893   U2OS-05_4_O20    911
# 19894   U2OS-05_4_O21    911
# 19895   U2OS-05_4_O22    911
# 19896   U2OS-05_4_O23    911
#
# [19897 rows x 2 columns]
